# %% [markdown]
# # Vectors and matrices

# %% [markdown]
# ### **Exercise 1** – **Vector product**
#
# Calculate for
# $$
# v' = (-1,\ 0,\ 3,\ -2)
# $$
# and
# $$
# w = (2,\ 3,\ -1,\ -3)'
# $$
# the following expressions:
#
# a) $$v' w$$
# b) $$v' v$$
# c) $$w' \cdot w \cdot v$$
# d) $$w \cdot v' \cdot w$$
#
# In subtasks **c)** and **d)**, consider the dimensions of the vectors in order to figure out which product has to be calculated first.

# %% [markdown]
# ### **Exercise 2** – **Orthogonality**
#
# Determine the components \( x, y \) and \( z \) such that the vectors
# $$
# v_1 = (1,\ 2,\ -1)'
# $$
# $$
# v_2 = (4,\ 2,\ x)'
# $$
# $$
# v_3 = (y,\ z,\ 1)'
# $$
# are pairwise orthogonal to each other.

# %% [markdown]
# ### **Exercise 3** – **Linear Combination**
#
# The vectors
# $$
# v_1 = (1,\ 1,\ 1)'
# $$
# $$
# v_2 = (1,\ 2,\ 3)'
# $$
# $$
# v_3 = (2,\ -1,\ 1)'
# $$
# are given. Show that the vector
# $$
# w = (1,\ -2,\ 5)'
# $$
# can be described as a linear combination of the vectors \( v_1, v_2 \) and \( v_3 \).

# %% [markdown]
# ### **Exercise 4** – **Matrix Multiplication**
#
# Decide whether the matrix multiplications $ \boldsymbol{A} \cdot \boldsymbol{B} $ and $ \boldsymbol{B} \cdot \boldsymbol{A} $ are possible and, if so, carry them out.
#
# a)
# $$
# \boldsymbol{A} = \begin{pmatrix}
# 2 & 1 & -1 \\
# 0 & 4 & 2
# \end{pmatrix},
# \quad
# \boldsymbol{B} = \begin{pmatrix}
# -1 & 1 & 0 & 3 \\
# 1 & 1 & 1 & 1 \\
# 0 & 2 & -3 & 4
# \end{pmatrix}
# $$
#
# b)
# $$
# \boldsymbol{A} = \begin{pmatrix}
# -2 & 1 & 2 \\
# 1 & 2 & -3
# \end{pmatrix},
# \quad
# \boldsymbol{B} = \begin{pmatrix}
# 3 & 2 \\
# 1 & 2
# \end{pmatrix}
# $$
#
# c)
# $$
# \boldsymbol{A} = \begin{pmatrix}
# 1 \\
# 2 \\
# 2
# \end{pmatrix},
# \quad
# \boldsymbol{B} = \begin{pmatrix}
# -2 & 0 & 1
# \end{pmatrix}
# $$
#
# d)
# $$
# \boldsymbol{A} = \begin{pmatrix}
# 1 & -3 & 4 \\
# 0 & 1 & -2 \\
# 2 & 2 & -1
# \end{pmatrix},
# \quad
# \boldsymbol{B} = \begin{pmatrix}
# 3 & 5 & 2 \\
# -4 & -9 & 2 \\
# -2 & -8 & 1
# \end{pmatrix}
# $$
#
# e)
# $$
# \boldsymbol{A} = \begin{pmatrix}
# 2 & 5 \\
# 1 & 3
# \end{pmatrix},
# \quad
# \boldsymbol{B} = \begin{pmatrix}
# 3 & -5 \\
# -1 & 2
# \end{pmatrix}
# $$
#
# f)
# $$
# \boldsymbol{A} = \begin{pmatrix}
# 1 & 5 & 0 \\
# 2 & 6 & 6 \\
# 3 & 7 & 4 \\
# 0 & 8 & 2
# \end{pmatrix},
# \quad
# \boldsymbol{B} = \boldsymbol{A}'
# $$

# %% [markdown]
# ### **Exercise 5** – **Matrix Algebra**
#
# Apply the calculation rules for matrix algebra in order to simplify the following expressions:
#
# a) $ \boldsymbol{A}(\boldsymbol{B}\boldsymbol{A})^{-1}\boldsymbol{B} $
#
# b) $ (\boldsymbol{A}\boldsymbol{B}')'(\boldsymbol{B}\boldsymbol{A}')^{-1}\boldsymbol{C} $
#
# c) $ \boldsymbol{A}\boldsymbol{B}'(\boldsymbol{B}^{-1})'\boldsymbol{A}^{-1} $

# %% [markdown]
# ### **Exercise 6** – **Matrix Algebra**
#
# Solve each of the following matrix equations for $X$ applying the calculation rules for matrices:
#
# a) $A'X' = [A(I + B)]'$
#
# b) $(XA + IX)' = A' + I$
#
# c) $X(A + I) = I + A^{-1}$
#
# $I$: appropriate identity matrix

# %% [markdown]
# ### **Exercise 7** – **Determinant**
#
# Calculate the determinant for the following matrices:
#
# a)
# $$
# A = \begin{pmatrix}
# 4 & 1 \\
# -4 & 2
# \end{pmatrix}
# $$
#
# b)
# $$
# B = \begin{pmatrix}
# 1 & -4 & -10 \\
# 10 & -8 & 2 \\
# 0 & -1 & 6
# \end{pmatrix}
# $$
#
# c)
# $$
# C = \begin{pmatrix}
# -7 & 1 & -10 \\
# 1 & 10 & 2 \\
# 1 & 0 & 6
# \end{pmatrix}
# $$
#
# d)
# $$
# D = \begin{pmatrix}
# -3 & 0 & -8 & 7 \\
# -7 & 1 & -4 & -10 \\
# 1 & 10 & -8 & 2 \\
# 1 & 0 & -1 & 6
# \end{pmatrix}
# $$
#
# e) $$E = D^{-1}$$
#
# f)
# $$
# F = \begin{pmatrix}
# 3 & 0 & 8 & -7 \\
# 7 & -1 & 4 & 10 \\
# -1 & -10 & 8 & -2 \\
# -1 & 0 & 1 & -6
# \end{pmatrix}
# $$

# %% [markdown]
# ### **Exercise 8** – **Determinant**
#
# The matrices
# $$
# A = \begin{pmatrix}
# 0 & 1 & 3 \\
# 2 & 5 & 7 \\
# 3 & 0 & 1
# \end{pmatrix}
# $$
# and
# $$
# B = \begin{pmatrix}
# 2 & 3 & 1 \\
# 0 & 2 & 5 \\
# 1 & 0 & 1
# \end{pmatrix}
# $$
# are given.
#
# a) Compute the determinant of $A$.
#
# b) Compute the determinant of a matrix that we receive by interchanging the first and the third column of $A$ (second column $A$ unchanged). Compare your result to a).
#
# c) Compute the determinant of $A'$. Compare your result to a).
#
# d) Compute the determinant of $2 \cdot A$. How can you compute this determinant more quickly?
#
# e) Compute the determinant of $B$.
#
# f) Compute the determinant of $A B$. Compare your result to a) and e).
#
# g) Compute the determinant of $A + B$. Compare your result to $det(A) + det(B)$.

# %% [markdown]
# ### **Exercise 9** – **Calculation of the Inverse**
#
# Calculate the inverse if possible:
#
# a)
# $$
# A = \begin{pmatrix}
# 4 & 1 \\
# -4 & 2
# \end{pmatrix}
# $$
#
# b)
# $$
# B = \begin{pmatrix}
# 4 & 1 \\
# -2 & -0.5
# \end{pmatrix}
# $$
#
# c)
# $$
# C = \begin{pmatrix}
# 1 & 2 \\
# 3 & -4
# \end{pmatrix}
# $$
#
# d)
# $$
# D = \begin{pmatrix}
# 1 & 0 & 0 \\
# 0 & 2 & -3 \\
# 0 & -1 & 3
# \end{pmatrix}
# $$

# %% [markdown]
# ### **Exercise 10** – **Rank, Regularity and Inverse**
#
# The following matrix is given:
# $$
# A = \begin{pmatrix}
# 1 & -1 & 2 \\
# 1 & 0 & 3 \\
# 4 & 0 & 2
# \end{pmatrix}
# $$
#
# a) Determine the rank of the matrix.
#
# b) Is the matrix $A$ regular or singular?
#
# c) Calculate the inverse of $A$, if possible.

# %% [markdown]
# ### **Exercise 11** – **Linear Equation Systems**
#
# Determine for the following linear equation system the solution vector using:
#
# a) Gaussian Elimination
#
# b) Matrix Inversion
#
# c) Cramer's Rule
#
# The system:
# $$
# \begin{align*}
# x_2 + x_3 &= -1 \\
# 3x_1 + 4x_2 + 5x_3 &= -2 \\
# 4x_1 + 6x_2 + 8x_3 &= -4
# \end{align*}
# $$

# %% [markdown]
# ### **Exercise 12** – **Rank of a Matrix**
#
# Determine the rank of the following matrices using Gaussian Elimination:
#
# a)
# $$
# A = \begin{pmatrix}
# 2 & 1 & 0 & 1 & 2 \\
# -1 & 2 & 1 & 0 & -1 \\
# 0 & 4 & 1 & 2 & 1
# \end{pmatrix}
# $$
#
# b)
# $$
# B = \begin{pmatrix}
# 4 & 2 & 1 \\
# -2 & 1 & 2 \\
# 1 & 0 & 3 \\
# -1 & -1 & -1
# \end{pmatrix}
# $$

# %% [markdown]
# ### **Exercise 13** – **Inverse of a Matrix**
#
# Given the matrix $A$:
# $$
# A = \begin{bmatrix}
# 2 & 1 & 3 \\
# 1 & 4 & 2 \\
# 3 & 5 & 1
# \end{bmatrix}
# $$
#
# - Find the inverse of matrix $A$, if it exists.
# - Verify that multiplying $A$ with its inverse results in the identity matrix.

# %% [markdown]
# ### **Exercise 14** – **Linear regression**
#
# In linear regression, the solution to $Xw = y$ is given by:
# $$w = (X^T X)^{-1} X^T y$$
#
# Given:
# $$X = \begin{bmatrix} 1 & 2 \\ 3 & 4 \\ 5 & 6 \end{bmatrix}, \quad y = \begin{bmatrix} 7 \\ 8 \\ 9 \end{bmatrix}$$
#
# - Find $w$
